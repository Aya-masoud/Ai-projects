# %%
from bs4 import BeautifulSoup
import requests
import csv

# %%
requests.get(r'https://www.bayt.com/en/egypt/jobs/ai-engineering-jobs/')
# Out:
# <Response [200]>

# %%
websit=requests.get(r'https://www.bayt.com/en/egypt/jobs/ai-engineering-jobs/').text

# %%
websit
# Out:
# '<!doctype html>\n<html lang="en" dir="ltr">\n<head>\n<link rel="preconnect" href="https://secure.b8cdn.com">\n<link rel="preconnect" href="https://fonts.gstatic.com/" crossorigin>\n<link rel="preconnect" href="https://cdn-cookieyes.com/">\n<link rel="dns-prefetch" href="https://secure.b8cdn.com">\n<link rel="dns-prefetch" href="https://fonts.gstatic.com/">\n<link rel="dns-prefetch" href="https://cdn-cookieyes.com/">\n<link rel="dns-prefetch" href="https://log.cookieyes.com/">\n<link rel="dns-prefetch" href="https://directory.cookieyes.com/">\n<meta name="keywords" content="ai engineering jobs in egypt, ai engineering vacancies egypt, ai engineering career opportunities in egypt">\n<meta charset="UTF-8">\n<meta name="viewport" content="width=device-width, initial-scale=1.0">\n<meta name="copyright" content="Bayt.com FZ-LLC">\n<meta name="referrer" content="strict-origin-when-cross-origin">\n<meta property="fb:app_id" data-js-id="meta-fb_app_id" content="116830345011417">\n<meta prope
# ...

# %%
mywebsit=BeautifulSoup(websit,'lxml')

# %%
mywebsit.title.text
# Out:
# 'Ai Engineering Jobs in Egypt (Mar 2025) - Bayt.com'

# %%
jobs=mywebsit.find('li',attrs="has-pointer-d")

# %%
len(jobs)
# Out:
# 9

# %%
jobtitle=mywebsit.find('div', attrs="row is-compact is-m no-wrap").text

# %%
print(jobtitle)
# Out:
# Sr. R&D Scientist MENAP Biscuits & Baked Goods

# %%
location=mywebsit.find_all('div',attrs="t-mute t-small")

# %%
len(location)
# Out:
# 20

# %%
companyNmae=mywebsit.find('div',class_="t-nowrap").text
print(companyNmae)
# Out:
# Mondelez
# Egypt

# %%
len(companyNmae)
# Out:
# 40

# %%
jobsrequ=mywebsit.find_all('div',attrs="jb-descr m10t t-small")

# %%
len(jobsrequ)
# Out:
# 20

# %%
for job in range(len(jobtitle)):
    jobtitle=mywebsit.find_all('div', attrs="row is-compact is-m no-wrap")
    location=mywebsit.find_all('div',attrs="t-mute t-small")
    companyNmae=mywebsit.find_all('div',class_="t-mute t-small")
    jobsrequ=mywebsit.find_all('div',attrs="jb-descr m10t t-small")
    print(jobtitle[job].text,location[job].text,companyNmae[job].text,jobsrequ[job].text)
# Out:
# Sr. R&D Scientist MENAP Biscuits & Baked Goods
#
#
#
#  Egypt Egypt
# Sr. R&D Scientist MENAP Biscuits & Baked Goods page is loaded Sr. R&D Scientist MENAP Biscuits & Baked Goods locations10th…
#
#
#
# Sr. R&D Scientist MENAP Biscuits & Baked Goods
#
#
#
#  Egypt Egypt
# Job Description Are You Ready to Make It Happen at Mondelēz International? Business Unit Summary Mondelēz International, Inc. empowers…
#
#
#
# Senior Machine Learning Engineer
#
#
#
#  Egypt Egypt
# As we embark on integrating AI into our operations for the ... looking for a trailblazing Senior AI Engineer to lay the foundation ... by the challenge of building AI systems...
#
#
#
# Staff Machine Learning Engineer
#
#
#
#  Cairo · Egypt Cairo · Egypt
# Staff Machine Learning Engineer Full-time Employee Type: Regular Region: EMEA - Europe, Middle East and Africa Work Persona: Flexible…
#
#
#
# Applied Scientist
#
#
#
#  Cairo · Egypt Cairo · Egypt
# ...

# %%
for i in range(1,6):
    url=f'https://www.bayt.com/en/egypt/jobs/ai-engineering-jobs/?page={i}&_gl=1*180kvvm*_up*MQ..*_ga*MTcxNjkxMzA0My4xNzQxODk5Nzky*_ga_1NKPLGNKKD*MTc0MTg5OTc5MS4xLjAuMTc0MTg5OTc5MS4wLjAuMA..'
    websit2=requests.get(url).text
    mywebsite2=BeautifulSoup(websit2,'lxml')
    jobs=mywebsite2.find('li',attrs="has-pointer-d")
    for job in jobs:
        jobtitle=job.find_all('div', attrs="row is-compact is-m no-wrap")
        location=job.find_all('div',attrs="t-mute t-small")
        companyNmae=job.find_all('div',class_="t-mute t-small")
        jobsrequ=job.find_all('div',attrs="jb-descr m10t t-small")
        print(jobtitle[job].text,location[job].text,companyNmae[job].text,jobsrequ[job].text)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14244\849223634.py in <module>
#       5     jobs=mywebsite2.find('li',attrs="has-pointer-d")
#       6     for job in jobs:
# ----> 7         jobtitle=job.find_all('div', attrs="row is-compact is-m no-wrap")
#       8         location=job.find_all('div',attrs="t-mute t-small")
#       9         companyNmae=job.find_all('div',class_="t-mute t-small")
#
# d:\programming\artifical intelligance\Programs\anacondaInstall\lib\site-packages\bs4\element.py in __getattr__(self, attr)
#     963             return self
#     964         else:
# --> 965             raise AttributeError(
#     966                 "'%s' object has no attribute '%s'" % (
#     967                     self.__class__.__name__, attr))
#
# AttributeError: 'NavigableString' object has no attribute 'find_all'

# %%
for i in range(1,6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
csvfilebs4=open('bs4scrapping1.csv','w',encoding='utf-8')
csvwriter=csv.writer(csvfilebs4)
csvwriter.writerow(['jobtitle','location','company name','job discreption'])
# Out:
# 49

# %%
for i in range(1,7):
    url=f'https://www.bayt.com/en/egypt/jobs/ai-engineering-jobs/?page={i}&_gl=1*180kvvm*_up*MQ..*_ga*MTcxNjkxMzA0My4xNzQxODk5Nzky*_ga_1NKPLGNKKD*MTc0MTg5OTc5MS4xLjAuMTc0MTg5OTc5MS4wLjAuMA..'
    websit2=requests.get(url).text
    mywebsite2=BeautifulSoup(websit2,'lxml')
    # jobs=mywebsite2.find_all('li',attrs="has-pointer-d")
    jobs = mywebsite2.find_all('li', attrs="has-pointer-d")
    for job in jobs:
        jobtitle = job.find('div', attrs="row is-compact is-m no-wrap").text
        location = job.find('div', attrs="t-mute t-small").text
        companyName=mywebsite2.find('div',class_="t-nowrap").text
        print(f"Job Title: {jobtitle}")
        print(f"Location: {location}")
        print(f"Company Name: {companyName}")

        # jobsrequ=mywebsit.find_all('div',attrs="jb-descr m10t t-small")
        # csvwriter.writerow([jobtitle,location,companyNmae,jobsrequ])
# Out:
# Job Title:
#
#
# Sr. R&D Scientist MENAP Biscuits & Baked Goods
#
#
#
#
# Location: Egypt
# Company Name:
# Mondelez
# Egypt
#
# Job Title:
#
#
# Sr. R&D Scientist MENAP Biscuits & Baked Goods
#
#
#
#
# Location: Egypt
# Company Name:
# Mondelez
# Egypt
#
# Job Title:
#
#
# Senior Machine Learning Engineer
#
#
#
#
# Location: Egypt
# Company Name:
# Mondelez
# Egypt
#
# Job Title:
#
#
# Staff Machine Learning Engineer
#
#
#
#
# Location: Cairo · Egypt
# Company Name:
# Mondelez
# Egypt
#
# Job Title:
#
#
# Applied Scientist
#
#
#
#
# Location: Cairo · Egypt
# Company Name:
# Mondelez
# Egypt
#
# Job Title:
#
#
# Senior Machine Learning Engineer
#
#
#
#
# Location: Cairo · Egypt
# Company Name:
# Mondelez
# Egypt
#
# Job Title:
#
#
# Machine Learning Engineer (VOIS)
#
#
#
#
# Location: Cairo · Egypt
# Company Name:
# Mondelez
# Egypt
#
# Job Title:
#
#
# Senior Machine Learning Engineer - Octopus by RTG
#
#
#
#
# Location: Egypt
# Company Name:
# Mondelez
# Egypt
#
# Job Title:
#
#
# ...

# %%
csvfilebs4=open('bs4scrapping0.csv','w',encoding='utf-8')
csvwriter=csv.writer(csvfilebs4)
csvwriter.writerow(['jobtitle','location','companyName','jobsrequ'])
# Out:
# 40

# %%
for i in range(1,6):
    url=f'https://www.bayt.com/en/egypt/jobs/ai-engineering-jobs/?page={i}&_gl=1*180kvvm*_up*MQ..*_ga*MTcxNjkxMzA0My4xNzQxODk5Nzky*_ga_1NKPLGNKKD*MTc0MTg5OTc5MS4xLjAuMTc0MTg5OTc5MS4wLjAuMA..'
    websit2=requests.get(url).text
    mywebsite2=BeautifulSoup(websit2,'lxml')
    jobs=mywebsite2.find_all('li',class_="has-pointer-d")
        
   
    for job in jobs:
        jobtitle = job.find('div', attrs="row is-compact is-m no-wrap").text
        location = job.find('div', attrs="t-mute t-small").text
        companyName=mywebsite2.find('div',class_="t-nowrap").text  
        jobsrequ=job.find('div',class_="jb-descr m10t t-small").text
        csvwriter.writerow([jobtitle,location,companyName,jobsrequ])
