# %%
import pandas as pd 
import numpy as np

# %%
data=pd.read_csv("dataset.csv",sep=";")
data.head()
# Out:
#    Marital status  Application mode  Application order  Course  \
# 0               1                 8                  5       2
# 1               1                 6                  1      11
# 2               1                 1                  5       5
# 3               1                 8                  2      15
# 4               2                12                  1       3
#
#    Daytime/evening attendance  Previous qualification  Nacionality  \
# 0                           1                       1            1
# 1                           1                       1            1
# 2                           1                       1            1
# 3                           1                       1            1
# 4                           0                       1            1
#
#    Mother's qualification  Father's qualification  Mother's occupation  ...  \
# 0                      13                      10                    6  ...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4424 entries, 0 to 4423
# Data columns (total 35 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Marital status                                  4424 non-null   int64
#  1   Application mode                                4424 non-null   int64
#  2   Application order                               4424 non-null   int64
#  3   Course                                          4424 non-null   int64
#  4   Daytime/evening attendance                      4424 non-null   int64
#  5   Previous qualification                          4424 non-null   int64
#  6   Nacionality                                     4424 non-null   int64
#  7   Mother's qualification                          4424 non-null   int64
#  8   Father's qualification                          4424 non-null   int64
# ...

# %%
data.isna().sum()
# Out:
# Marital status                                    0
# Application mode                                  0
# Application order                                 0
# Course                                            0
# Daytime/evening attendance                        0
# Previous qualification                            0
# Nacionality                                       0
# Mother's qualification                            0
# Father's qualification                            0
# Mother's occupation                               0
# Father's occupation                               0
# Displaced                                         0
# Educational special needs                         0
# Debtor                                            0
# Tuition fees up to date                           0
# Gender                                            0
# Scholarship holder                                0
# Age at enrollment                                 0
# ...

# %%
data.describe()
# Out:
#        Marital status  Application mode  Application order       Course  \
# count     4424.000000       4424.000000        4424.000000  4424.000000
# mean         1.178571          6.886980           1.727848     9.899186
# std          0.605747          5.298964           1.313793     4.331792
# min          1.000000          1.000000           0.000000     1.000000
# 25%          1.000000          1.000000           1.000000     6.000000
# 50%          1.000000          8.000000           1.000000    10.000000
# 75%          1.000000         12.000000           2.000000    13.000000
# max          6.000000         18.000000           9.000000    17.000000
#
#        Daytime/evening attendance  Previous qualification  Nacionality  \
# count                 4424.000000             4424.000000  4424.000000
# mean                     0.890823                2.531420     1.254521
# std                      0.311897                3.963707     1.748447
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.countplot(data.Target, palette="bwr")
plt.show()
data.Target.value_counts()
# Out:
# d:\programming\artifical intelligance\Programs\anacondaInstall\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Graduate    2209
# Dropout     1421
# Enrolled     794
# Name: Target, dtype: int64

# %%
cols_name=data.columns

# %%
cols_name
# Out:
# Index(['Marital status', 'Application mode', 'Application order', 'Course',
#        'Daytime/evening attendance', 'Previous qualification', 'Nacionality',
#        'Mother's qualification', 'Father's qualification',
#        'Mother's occupation', 'Father's occupation', 'Displaced',
#        'Educational special needs', 'Debtor', 'Tuition fees up to date',
#        'Gender', 'Scholarship holder', 'Age at enrollment', 'International',
#        'Curricular units 1st sem (credited)',
#        'Curricular units 1st sem (enrolled)',
#        'Curricular units 1st sem (evaluations)',
#        'Curricular units 1st sem (approved)',
#        'Curricular units 1st sem (grade)',
#        'Curricular units 1st sem (without evaluations)',
#        'Curricular units 2nd sem (credited)',
#        'Curricular units 2nd sem (enrolled)',
#        'Curricular units 2nd sem (evaluations)',
#        'Curricular units 2nd sem (approved)',
#        'Curricular units 2nd sem (grade)',
# ...

# %%
from category_encoders import OrdinalEncoder 
encoder=OrdinalEncoder(cols=["Target"])
data=encoder.fit_transform(data)
data=pd.DataFrame(data,columns=cols_name)
data.head()
# Out:
#    Marital status  Application mode  Application order  Course  \
# 0               1                 8                  5       2
# 1               1                 6                  1      11
# 2               1                 1                  5       5
# 3               1                 8                  2      15
# 4               2                12                  1       3
#
#    Daytime/evening attendance  Previous qualification  Nacionality  \
# 0                           1                       1            1
# 1                           1                       1            1
# 2                           1                       1            1
# 3                           1                       1            1
# 4                           0                       1            1
#
#    Mother's qualification  Father's qualification  Mother's occupation  ...  \
# 0                      13                      10                    6  ...
# ...

# %%
data.Target.value_counts()
# Out:
# 2    2209
# 1    1421
# 3     794
# Name: Target, dtype: int64

# %%
data = data[data['Target'] != 3]

# %%
X = data.drop("Target",axis=1)
y = data["Target"]

# %%
from sklearn import preprocessing
X= preprocessing.StandardScaler().fit_transform(X)

# %%
X=pd.DataFrame(X,columns=data.drop("Target",axis=1).columns)
X.head()
# Out:
#    Marital status  Application mode  Application order    Course  \
# 0       -0.300686          0.226505           2.436822 -1.828415
# 1       -0.300686         -0.154237          -0.562471  0.245261
# 2       -0.300686         -1.106094           2.436822 -1.137190
# 3       -0.300686          0.226505           0.187353  1.166895
# 4        1.330837          0.987990          -0.562471 -1.598007
#
#    Daytime/evening attendance  Previous qualification  Nacionality  \
# 0                    0.355850               -0.392879    -0.142589
# 1                    0.355850               -0.392879    -0.142589
# 2                    0.355850               -0.392879    -0.142589
# 3                    0.355850               -0.392879    -0.142589
# 4                   -2.810171               -0.392879    -0.142589
#
#    Mother's qualification  Father's qualification  Mother's occupation  ...  \
# 0                0.049009               -0.606253            -0.327219  ...
# ...

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.2, random_state=10)

# %%
from sklearn.feature_selection import RFECV
from sklearn.ensemble import RandomForestClassifier
rfc=RandomForestClassifier()
model=RFECV(estimator=rfc,cv=5,step=22)
model.fit(X_train,y_train)
y_pred_rfc=model.predict(X_test)

# %%
print(f'Optimal number of features: {model.n_features_}')
print(f'Selected features: {list(X.columns[model.support_])}')
# Out:
# Optimal number of features: 34
# Selected features: ['Marital status', 'Application mode', 'Application order', 'Course', 'Daytime/evening attendance', 'Previous qualification', 'Nacionality', "Mother's qualification", "Father's qualification", "Mother's occupation", "Father's occupation", 'Displaced', 'Educational special needs', 'Debtor', 'Tuition fees up to date', 'Gender', 'Scholarship holder', 'Age at enrollment', 'International', 'Curricular units 1st sem (credited)', 'Curricular units 1st sem (enrolled)', 'Curricular units 1st sem (evaluations)', 'Curricular units 1st sem (approved)', 'Curricular units 1st sem (grade)', 'Curricular units 1st sem (without evaluations)', 'Curricular units 2nd sem (credited)', 'Curricular units 2nd sem (enrolled)', 'Curricular units 2nd sem (evaluations)', 'Curricular units 2nd sem (approved)', 'Curricular units 2nd sem (grade)', 'Curricular units 2nd sem (without evaluations)', 'Unemployment rate', 'Inflation rate', 'GDP']

# %%
from sklearn.metrics import confusion_matrix,classification_report,roc_curve,auc
print("RandomForestClassifier")
print(classification_report(y_test, y_pred_rfc,digits=4))

cm = confusion_matrix(y_test, y_pred_rfc)
plt.figure(figsize=(5, 4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

#  Draw the roc curev and auc using the results of random forest
# ROC Curve and AUC
y_pred_proba = model.predict_proba(X_test)[:, 1]
fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba,pos_label=2)
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.4f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()
# Out:
# RandomForestClassifier
#               precision    recall  f1-score   support
#
#            1     0.9345    0.8735    0.9030       245
#            2     0.9376    0.9688    0.9530       481
#
#     accuracy                         0.9366       726
#    macro avg     0.9361    0.9211    0.9280       726
# weighted avg     0.9366    0.9366    0.9361       726

# %%
from sklearn.linear_model import LogisticRegression,SGDClassifier
lr=LogisticRegression(max_iter=1000)
model=RFECV(estimator=lr,step=25,cv=5)
model.fit(X_train,y_train)
y_pred_lr=model.predict(X_test)


print(f'Optimal number of features: {model.n_features_}')
print(f'Selected features: {list(X.columns[model.support_])}')
# Out:
# Optimal number of features: 34
# Selected features: ['Marital status', 'Application mode', 'Application order', 'Course', 'Daytime/evening attendance', 'Previous qualification', 'Nacionality', "Mother's qualification", "Father's qualification", "Mother's occupation", "Father's occupation", 'Displaced', 'Educational special needs', 'Debtor', 'Tuition fees up to date', 'Gender', 'Scholarship holder', 'Age at enrollment', 'International', 'Curricular units 1st sem (credited)', 'Curricular units 1st sem (enrolled)', 'Curricular units 1st sem (evaluations)', 'Curricular units 1st sem (approved)', 'Curricular units 1st sem (grade)', 'Curricular units 1st sem (without evaluations)', 'Curricular units 2nd sem (credited)', 'Curricular units 2nd sem (enrolled)', 'Curricular units 2nd sem (evaluations)', 'Curricular units 2nd sem (approved)', 'Curricular units 2nd sem (grade)', 'Curricular units 2nd sem (without evaluations)', 'Unemployment rate', 'Inflation rate', 'GDP']

# %%
from sklearn.metrics import confusion_matrix,classification_report,roc_curve,auc
print("LogisticRegression")
print(classification_report(y_test, y_pred_lr,digits=4))

cm = confusion_matrix(y_test, y_pred_lr)
plt.figure(figsize=(5, 4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()


y_pred_proba = model.predict_proba(X_test)[:, 1]
fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba,pos_label=2)
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.4f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()
# Out:
# LogisticRegression
#               precision    recall  f1-score   support
#
#            1     0.9417    0.8571    0.8974       245
#            2     0.9304    0.9730    0.9512       481
#
#     accuracy                         0.9339       726
#    macro avg     0.9361    0.9151    0.9243       726
# weighted avg     0.9342    0.9339    0.9331       726

# %%
from sklearn.linear_model import LogisticRegression,SGDClassifier
sGDClassifier=SGDClassifier(max_iter=1000,loss="log")
model=RFECV(estimator=sGDClassifier,step=25,cv=5)
model.fit(X_train,y_train)
y_pred_lr=model.predict(X_test)



print(f'Optimal number of features: {model.n_features_}')
print(f'Selected features: {list(X.columns[model.support_])}')
# Out:
# Optimal number of features: 9
# Selected features: ['Course', 'Tuition fees up to date', 'International', 'Curricular units 1st sem (credited)', 'Curricular units 1st sem (enrolled)', 'Curricular units 1st sem (approved)', 'Curricular units 1st sem (grade)', 'Curricular units 2nd sem (enrolled)', 'Curricular units 2nd sem (approved)']

# %%
from sklearn.metrics import confusion_matrix,classification_report,roc_curve,auc
print("SGDClassifier")
print(classification_report(y_test, y_pred_lr,digits=4))

cm = confusion_matrix(y_test, y_pred_lr)
plt.figure(figsize=(5, 4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()


y_pred_proba = model.predict_proba(X_test)[:, 1]
fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba,pos_label=2)
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.4f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()
# Out:
# SGDClassifier
#               precision    recall  f1-score   support
#
#            1     0.9398    0.8286    0.8807       245
#            2     0.9176    0.9730    0.9445       481
#
#     accuracy                         0.9242       726
#    macro avg     0.9287    0.9008    0.9126       726
# weighted avg     0.9251    0.9242    0.9230       726

# %%
from sklearn.model_selection import GridSearchCV
sGDClassifier=SGDClassifier()
para_grid={
             "loss": ['hinge', 'log_loss', 'log', 'modified_huber', 'squared_hinge', 'perceptron'],
              "penalty": ['l2', 'l1', 'elasticnet'] ,
              "alpha": [ 0.0001,0.001,0.01,0.1],
              "max_iter": [1000,1100,1300],
            
}
grid_model=GridSearchCV(estimator=sGDClassifier,scoring="accuracy",param_grid=para_grid,cv=5,verbose=-1,n_jobs=-1)

grid_model.fit(X_train, y_train)

model=RFECV(estimator=grid_model.best_estimator_,step=25,cv=5)
model.fit(X_train,y_train)
y_pred_lr=model.predict(X_test)
# Out:
# d:\programming\artifical intelligance\Programs\anacondaInstall\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 180 fits failed out of a total of 1080.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 180 fits failed with the following error:
# Traceback (most recent call last):
#   File "d:\programming\artifical intelligance\Programs\anacondaInstall\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "d:\programming\artifical intelligance\Programs\anacondaInstall\lib\site-packages\sklearn\linear_model\_stochastic_gradient.py", line 883, in fit
#     return self._fit(
# ...

# %%
print(f'Optimal number of features: {model.n_features_}')
print(f'Selected features: {list(X.columns[model.support_])}')
# Out:
# Optimal number of features: 34
# Selected features: ['Marital status', 'Application mode', 'Application order', 'Course', 'Daytime/evening attendance', 'Previous qualification', 'Nacionality', "Mother's qualification", "Father's qualification", "Mother's occupation", "Father's occupation", 'Displaced', 'Educational special needs', 'Debtor', 'Tuition fees up to date', 'Gender', 'Scholarship holder', 'Age at enrollment', 'International', 'Curricular units 1st sem (credited)', 'Curricular units 1st sem (enrolled)', 'Curricular units 1st sem (evaluations)', 'Curricular units 1st sem (approved)', 'Curricular units 1st sem (grade)', 'Curricular units 1st sem (without evaluations)', 'Curricular units 2nd sem (credited)', 'Curricular units 2nd sem (enrolled)', 'Curricular units 2nd sem (evaluations)', 'Curricular units 2nd sem (approved)', 'Curricular units 2nd sem (grade)', 'Curricular units 2nd sem (without evaluations)', 'Unemployment rate', 'Inflation rate', 'GDP']

# %%
from sklearn.metrics import roc_auc_score
print("SGDClassifier")
print(classification_report(y_test, y_pred_lr,digits=4))

cm = confusion_matrix(y_test, y_pred_lr)
plt.figure(figsize=(5, 4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()


# y_pred_proba = model.predict(X_test)
# fpr, tpr, thresholds = roc_auc_score(y_test, y_pred_proba)
# roc_auc = auc(fpr, tpr)

# plt.figure()
# plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.4f)' % roc_auc)
# plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
# plt.xlim([0.0, 1.0])
# plt.ylim([0.0, 1.05])
# plt.xlabel('False Positive Rate')
# plt.ylabel('True Positive Rate')
# plt.title('Receiver Operating Characteristic')
# plt.legend(loc="lower right")
# plt.show()
# Out:
# SGDClassifier
#               precision    recall  f1-score   support
#
#            1     0.9181    0.8694    0.8931       245
#            2     0.9352    0.9605    0.9477       481
#
#     accuracy                         0.9298       726
#    macro avg     0.9267    0.9149    0.9204       726
# weighted avg     0.9294    0.9298    0.9293       726
